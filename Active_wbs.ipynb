# %% [markdown]
# # Tasks  list with current work sheet.

# %% [markdown]
# # Copilot Instructions

# %% [markdown]
# ## List
# 1. Active and archieve techhniques
# https://copilot.microsoft.com/shares/W52skbMsY6N6Q815aoWDi
# 2. running notebooks in sequence.
# https://copilot.microsoft.com/shares/k85YtYN1EWc8D5JjZdjcP

# %% [markdown]
# # Tasks  and the **workbooks** required

# %% [markdown]
# ## load xl... to df... all the way to plot from inbody folder  [souce for ib77 dfs]

# %% [markdown]
# ### ipynb ... for **ib77 wb**  is  **"col_wise_import_77"**

# %% [markdown]
# ### ipynb ... for **ib97 wb**  is  **"col_wise_import_97"**

# %% [markdown]
# ## Task ...    load xl... to df...  from inbody

# %% [markdown]
# ### ipynb ...

# %% [markdown]
# ### ipynb ...

# %% [markdown]
# ## Task ...    load xl... to df...  from inbody

# %% [markdown]
# ### ipynb ...

# %% [markdown]
# ### ipynb ...
