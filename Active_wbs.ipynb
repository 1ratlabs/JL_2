# %% [markdown]
# # Tasks  list with current work sheet.

# %% [markdown]
# #### plt_df_cstm.ipynb

# %% [markdown]
# #### bld_df_cstm.ipynb

# %% [markdown]
# #### col_wise_cmbn7797_to_df_ib.ipynb

# %% [markdown]
# ##### col_wise_import_77.ipynb

# %% [markdown]
# ##### col_wise_import_97.ipynb

# %% [markdown]
# # Copilot Instructions

# %% [markdown]
# ## List
# 1. Active and archieve techhniques
# https://copilot.microsoft.com/shares/W52skbMsY6N6Q815aoWDi
# 2. running notebooks in sequence.
# https://copilot.microsoft.com/shares/k85YtYN1EWc8D5JjZdjcP

# %% [markdown]
# # Tasks  and the **workbooks** required

# %% [markdown]
# ## col_wise_import ib770 individual test results to pickle [df_mf_ib77_nn_s]
# 1. ib770 exports test results to onedrive 1 csv file[uft-8] per test to ib77
# 2. manual copy file to repo/data ib77
# 3. import csv ib77 files to [df_ib77_raw]
# 4. strips off col numbers [df_ib77_nn]
# 5. Eliminate col duplicates [df_ib77_nn]
# 6. adds media data cols [df_m_ib77_nn]
# 7. computes media cols from data [df_mf_ib77_nn]
# 8. removes timestamp duplicates to get [df_mf_ib77_nn]
# 9. sorts via timestamp to get [df_mf_ib77_nn_s]
# 10. writes to Pickle [df_mf_ib77_nn_s]
# 11. misc functions to be removed

# %% [markdown]
# ### *ipynb ...* **"col_wise_import_77"**

# %% [markdown]
# ### *ipynb ...* **"col_wise_import_97"**

# %% [markdown]
# ### *STATUS ...* **"Work but need cleaning"**

# %% [markdown]
# ## col_wise_cmbn7797_to_df_ib >>>> concatinate "df_mf_ib77_nn_s" & "df_mf_ib97_nn_s" to "df_ib"
# 1.  combine **ib77** plus **ib97** test readings
# 2.  cleaned for dup rows and cols
# 3.  sorted by "timestamp"
# 4.  stored into pickle [df_ib]

# %% [markdown]
# ## Creating process dataframes that select groups to be filtered, correlated, and/or plotted
# 1.  Make a def function that slices select rows of a group
# 2.  Create a table of groups with name, description and col-lst
# 3.  save the group list to pickle.
# 4.

# %% [markdown]
# ## Creating process programs that specify the series of actions for a desired result
# 1.  Determine the sequence of functions and data respuired
# 2.  Read in the
# 3.

# %% [markdown]
# ## Create a function worksheet
# 1. Has a group of def functions such as plotters and filters
# 2. reads in groups from pickle
# 3. Reads in raw data from pickle
# 4. Reads in results data from pickle
# 5. Slices to the custom data sets.
# 6. performs a series of functions on the custom data sets
# 7. Stores the new results in pickle

# %% [markdown]
# # NEXT
